# %% [markdown]
# # EECS 545 (WN 2024) Homework 4: Transformers
#
# <span class="instruction">Before starting the assignment, please fill in the following cell.</span>

# %%
###################################################################
# Enter your first and last name, e.g. "John Doe"                 #
# for example                                                     #
__NAME__ = "Shashank Verma"                                          #
__UNIQID__ = "shaaero"                                         #
###################################################################
# raise NotImplementedError("TODO: Add your implementation here.")
###################################################################
#                        END OF YOUR CODE                         #
###################################################################

print(f"Your name and email: {__NAME__} <{__UNIQID__}@umich.edu>")
assert __NAME__ and __UNIQID__
# Out:
# Your name and email: Shashank Verma <shaaero@umich.edu>

# %% [markdown]
# # Transformer on text generation
# In this notebook, you will test the Attention Module and the PyTorch training code you implemented in **transformer.py** and **transformer_trainer.py**. This requires running code in PyTorch. Ideally, you should run this file on <span style="color: violet;">**GPU**</span>. If it is not available on your own machine, we recommand running on <span style="color: violet;">**Colab**</span>. Please refer to this [instruction](https://docs.google.com/document/d/e/2PACX-1vSgRhviaU_N_ErIwytT6vJ52gxmjiBcRGDs7q80qeifOVyuRkwZYchXMFn-HU0UjXrvmGzR2fB9QsOz/pub) about how to use Colab. If you evenatually decide to run everything with **CPU**, please start early and allocate at least a few hours for section(C) as it is going to take long.

# %% [markdown]
# ## Setup code
# Before getting started, we need to run some boilerplate code to set up our environment. You'll need to rerun this setup code each time you start the notebook. Let's start by checking whether we are using Python 3.11 or higher.

# %%
import sys
if sys.version_info[0] < 3:
    raise Exception("You must use Python 3")

if sys.version_info[1] < 11:
    print("Autograder will execute your code based on Python 3.11 environment. Please use Python 3.11 or higher to prevent any issues")
    print("You can create a conda environment with Python 3.11 like 'conda create --name eecs545 python=3.11'")
    # raise Exception("Python 3 version is too low: {}".format(sys.version))
else:
    print("You are good to go")
# Out:
# Autograder will execute your code based on Python 3.11 environment. Please use Python 3.11 or higher to prevent any issues
# You can create a conda environment with Python 3.11 like 'conda create --name eecs545 python=3.11'

# %% [markdown]
# First, run this cell load the [autoreload](https://ipython.readthedocs.io/en/stable/config/extensions/autoreload.html) extension. This allows us to edit `.py` source files, and re-import them into the notebook for a seamless editing and debugging experience.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = "HW4_rev0"  # TODO: Fill in the Google Drive path where you uploaded the assignment
WORKSPACE_PATH = os.path.join('drive', 'My Drive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)

# If you are running this code outside of Google Colab, please comment it out and fill in the path below
# WORKSPACE_PATH = "./"

print(os.listdir(WORKSPACE_PATH))
sys.path.append(WORKSPACE_PATH)
# Out:
# ['gradient_check.py', 'solver.py', 'optim.py', 'layers.py', 'coco_utils.py', 'captioning_solver.py', 'rough.py', 'cnn.py', 'image_utils.py', 'cnn.png', 'cnn.ipynb', 'rnn_layers.py', 'rnn.py', 'image_captioning_loss.png', 'rnn.ipynb', '.DS_Store', 'transfer_learning.py', 'transfer_learning.ipynb', 'cnn_layers.py', 'transformer.py', 'transformer_trainer.py', '__pycache__', 'data', 'transformer.ipynb']

# %% [markdown]
# Then, we run some setup code for this notebook: Import some useful packages and increase the default figure size.

# %%
# Uncomment the lines below to install packages if they are not installed yet.
# !pip install numpy==1.24.1 matplotlib==3.6.2 scikit-learn==1.2.0 imageio==2.25.1
import os
import sys
import json
import random

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Next, we need to make sure pytorch is installed. The following command will install pytorch if you haven't installed it before. Depending on your OS and GPU hardware, this may install a CPU or GPU version. If you want to use a GPU with PyTorch (which will exponentially speed up your computation time) you can follow the instructions on the pytorch [official website](https://pytorch.org/get-started/locally/). In this problem set a CPU-only pytorch is sufficient.

# %%
# uncomment and run the line below to install pytorch is you haven't done so
# !pip install torch==2.2.1 torchvision==0.17.1
import torch
from torch.utils.data import Dataset
from torch.utils.data.dataloader import DataLoader
# Out:
# Requirement already satisfied: torch==2.2.1 in /usr/local/lib/python3.10/dist-packages (2.2.1+cu121)
# Requirement already satisfied: torchvision==0.17.1 in /usr/local/lib/python3.10/dist-packages (0.17.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.2.1)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 26.8 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.2.1)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 39.7 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.2.1)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 34.6 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.2.1)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.5 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.2.1)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.7 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.2.1)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 5.0 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.2.1)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 7.1 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.2.1)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 6.2 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.2.1)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 2.4 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch==2.2.1)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 1.2 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.2.1)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1) (2.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision==0.17.1) (1.25.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision==0.17.1) (9.4.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch==2.2.1)
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.2.1) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.2.1) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105

# %%
# check if CUDA is available on torch
print('PyTorch CUDA is available?', torch.cuda.is_available())
# Out:
# PyTorch CUDA is available? True

# %% [markdown]
# To reproduce results, it is important to set seed. The function below helps to do so.

# %%
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

set_seed(12345) #set a fixed random seed

# %% [markdown]
# ### Section(A) Check your attention implementation
# Now, let's check your transformer implementation. A correct implementation should pass the assert_allclose line and does not trigger any error.

# %%
from transformer import MaskedAttention
set_seed(12345)
attention = MaskedAttention(48, 3, 3)
inputs = [[[ 0.8852, -1.1841,  0.4406,  0.6939, -0.8548, -0.7011,  0.2941,
           0.6334,  1.6439,  0.2185, -1.8231,  0.3305, -3.6633, -0.5477,
          -1.5629,  1.3776, -2.3223,  1.1882, -1.0146,  0.4610, -0.6772,
           1.0473,  0.6797, -1.3599,  0.5765,  1.3818,  1.9596,  0.2333,
           0.4236,  1.5104,  0.5365, -1.2894,  1.0061,  0.0317,  0.9216,
           0.8358, -0.0778,  0.2040,  0.5083, -1.4204, -0.5308,  0.5121,
           1.4943,  1.3703,  0.4305,  1.2011, -1.8800, -0.1506],
         [-0.1161,  1.0082,  1.1272,  1.0432, -0.5849, -1.9456, -0.5046,
          -0.0495, -0.1723, -0.7835,  0.0706, -1.1203, -0.5606,  0.6311,
          -0.4215, -1.4242,  0.5186,  1.2899, -1.6057, -0.7066,  0.0234,
           0.0535, -0.1760,  2.7153, -0.3977,  0.4018,  1.7233, -0.4099,
           0.8925, -1.6363,  0.5603,  0.8228, -0.6935,  0.5939,  0.0261,
          -0.8228,  1.0020,  0.8776,  0.2597,  0.5770, -0.7814,  0.4137,
          -3.1109,  1.5095, -1.3054, -0.2762, -0.2339, -0.0605],
         [-0.9684,  0.8253,  1.1051, -0.7230,  0.3950, -0.3346, -0.0271,
          -1.6035, -0.3299,  0.6642, -0.4004, -0.6389, -0.2243,  0.8469,
          -1.0028, -0.2318,  1.4500,  0.1103,  1.2395,  0.2621,  1.8836,
          -0.6182,  2.1644,  1.5504,  3.0542,  0.9740, -2.8405,  0.8848,
           0.2762, -0.7397,  1.5389, -0.6161, -0.3589, -0.0085,  0.1275,
          -0.2849, -0.6918, -1.7355, -1.0572, -0.4486, -0.5446,  0.8705,
           0.8601, -0.1449,  1.4177, -0.2919,  0.7602,  0.4350]]]
inputs = torch.tensor(inputs).float()
attention.eval()
with torch.no_grad():
    outputs = attention(inputs)
expected_outputs = np.array([[[-0.1486,  0.1777, -0.3494, -0.2162, -0.1077,  0.0685, -1.0346,
                              -0.6672, -0.8616, -0.3380,  0.2046, -0.0050, -0.0738,  0.1913,
                               0.1332, -0.3641, -0.4243,  0.1188,  0.0215,  0.2370,  0.6812,
                              -0.1018,  0.0788, -0.6371, -0.4669,  0.6068,  0.1693,  0.1214,
                              -0.8412, -0.1185, -0.2494,  0.4053,  0.3242, -0.0280,  0.3158,
                              -0.2219,  0.1630, -0.0745, -0.1231, -0.6197,  0.5833, -0.3247,
                               0.3002, -0.1323, -0.4823, -0.5536, -0.1559,  0.5801],
                             [ 0.0702,  0.1089, -0.4341, -0.0671, -0.2151, -0.0183, -0.5890,
                              -0.6078, -0.8475, -0.4055, -0.1759, -0.0395, -0.0636,  0.2831,
                               0.0722, -0.1965, -0.2158,  0.1390, -0.2303,  0.2821,  0.5404,
                               0.0640,  0.1459, -0.4615, -0.3691,  0.2262,  0.1783, -0.0748,
                              -0.6773, -0.1486, -0.0890,  0.5385,  0.0556,  0.0576,  0.1533,
                              -0.0288,  0.0889, -0.0435, -0.1417, -0.2416,  0.4084, -0.2700,
                               0.0975, -0.1606, -0.4313, -0.4773, -0.0866,  0.2469],
                             [-0.1378, -0.1708, -0.2168, -0.0777, -0.0604,  0.0068, -0.6403,
                              -0.3968, -0.3044, -0.1192, -0.4150,  0.2027,  0.0118,  0.1063,
                              -0.1213,  0.2542,  0.0388, -0.0865, -0.2399, -0.0096,  0.3200,
                               0.0793,  0.0022, -0.1296, -0.0470,  0.1209,  0.0395,  0.3965,
                              -0.2515, -0.3861, -0.3169,  0.0824,  0.2049,  0.1243, -0.1657,
                               0.0492, -0.1103,  0.1369,  0.1256, -0.4973,  0.1020, -0.1457,
                               0.1124, -0.2355, -0.4387, -0.4518, -0.0035,  0.0864]]])

np.testing.assert_allclose(outputs.cpu().numpy(), expected_outputs, atol=1e-3)
print("Passed!")
# Out:
# Passed!

# %% [markdown]
# ### Section(B) Train your model to learn multiplication.
# The code base below is a math multiplication dataset for n-digit multiplication. Specifically, we are focusing on 2-digit multiplication problem in this homework, for example, for input 54x45, the expected output is 2430.

# %%
class DigitMultiplicationDataset(Dataset):
    def __init__(self, n, data_comb, split):
        self.n = n # max number of digit
        n_train = int(0.8*data_num)
        self.data = data_comb[:n_train] if split == 'train' else data_comb[n_train:]

    def get_block_size(self):
        return 4*self.n - 1

    def __len__(self):
        return self.data.nelement()

    def digit_to_str(self, x, ndigit):
        return f'%0{ndigit}d' % x

    def str_to_digit(self, x, device):
        factors = torch.tensor([[10**i for i in range(x.shape[-1])][::-1]]).to(device)
        return (x * factors).sum(dim=1)

    def __getitem__(self, idx):
        inputs = self.data[idx].item()
        a, b = inputs // (10**self.n), inputs % (10**self.n)
        c = a * b # target
        # encode digits
        astr = self.digit_to_str(a, self.n)
        bstr = self.digit_to_str(b, self.n)
        cstr = self.digit_to_str(c, 2*self.n) #2-digit numbers multiply to up to 4 digits.
        # we ignore * symbol because we only finetune on multiplication.
        concat_str = f'{astr}{bstr}{cstr[::-1]}'
        concat = [int(s) for s in concat_str]
        x = torch.tensor(concat[:-1]).long() #given the sequence 01020
        y = torch.tensor(concat[1:]).long() #predict the next digit 10203
        y[:self.n*2-1] = -100 #masked out input
        return x, y

# generate data
ndigit=2
rng = torch.Generator()
rng.manual_seed(1337)
data_num = (10**ndigit)**2
data_comb = torch.randperm(data_num, generator=rng)

# %% [markdown]
# Run the code below to train a model that learns 2-digit number multiplication!
#
# If you are worried that the training break and you lose the training progress, you can refer to [PyTorch checkpoint](https://pytorch.org/tutorials/recipes/recipes/saving_and_loading_a_general_checkpoint.html) to save and load checkpoints while you train. Generally this will not happen for small models with short training time if you run on GPU.

# %%
from transformer import GPT
from transformer_trainer import Trainer, Evaluator

set_seed(12345)
train_dataset = DigitMultiplicationDataset(ndigit, data_comb, split='train')
test_dataset = DigitMultiplicationDataset(ndigit, data_comb, split='test')
n_layer, n_head, embedding_dim = 4, 4, 128
multip_model = GPT(n_layer,
                   n_head,
                   embedding_dim,
                   10, # 10 possible digits
                   train_dataset.get_block_size())

learning_rate = 1e-3
max_iters=20000
multip_trainer = Trainer(multip_model, train_dataset, learning_rate, max_iters=max_iters)
multip_trainer.test_dataset = test_dataset
multip_trainer.run('multiplication')
# Out:
# running on cuda
# Iteration 1/20000: training loss 2.3560
# train accuracy: 1.93%
# Iteration 501/20000: training loss 1.2026
# train accuracy: 4.49%
# Iteration 1001/20000: training loss 1.0056
# train accuracy: 6.97%
# Iteration 1501/20000: training loss 1.0613
# train accuracy: 9.32%
# Iteration 2001/20000: training loss 0.8498
# train accuracy: 12.74%
# Iteration 2501/20000: training loss 0.8783
# train accuracy: 17.48%
# Iteration 3001/20000: training loss 0.7716
# train accuracy: 18.93%
# Iteration 3501/20000: training loss 0.6095
# train accuracy: 26.23%
# Iteration 4001/20000: training loss 0.6799
# train accuracy: 29.29%
# Iteration 4501/20000: training loss 0.5950
# train accuracy: 33.17%
# Iteration 5001/20000: training loss 0.6255
# train accuracy: 38.02%
# Iteration 5501/20000: training loss 0.5409
# train accuracy: 40.79%
# Iteration 6001/20000: training loss 0.4882
# train accuracy: 44.26%
# Iteration 6501/20000: training loss 0.4693
# train accuracy: 48.55%
# Iteration 7001/20000: training loss 0.3932
# train accuracy: 52.34%
# Iteration 7501/20000: training loss 0.3855
# train accuracy: 58.00%
# Iteration 8001/20000: training loss 0.4080
# train accuracy: 58.15%
# Iteration 8501/20000: training loss 0.3215
# train accuracy: 62.10%
# Iteration 9001/20000: training loss 0.4342
# train accuracy: 63.46%
# Iteration 9501/20000: training loss 0.2837
# train accuracy: 68.40%
# Iteration 10001/20000: training loss 0.3195
# train accuracy: 72.51%
# Iteration 10501/20000: training loss 0.2318
# train accuracy: 76.47%
# Iteration 11001/20000: training loss 0.2446
# train accuracy: 78.46%
# Iteration 11501/20000: training loss 0.2518
# train accuracy: 82.28%
# Iteration 12001/20000: training loss 0.1693
# train accuracy: 87.11%
# Iteration 12501/20000: training loss 0.1619
# train accuracy: 88.44%
# Iteration 13001/20000: training loss 0.1734
# train accuracy: 90.83%
# Iteration 13501/20000: training loss 0.1368
# train accuracy: 92.29%
# Iteration 14001/20000: training loss 0.1191
# train accuracy: 93.21%
# Iteration 14501/20000: training loss 0.1062
# train accuracy: 95.84%
# Iteration 15001/20000: training loss 0.1094
# train accuracy: 95.14%
# Iteration 15501/20000: training loss 0.1146
# train accuracy: 96.95%
# Iteration 16001/20000: training loss 0.0883
# train accuracy: 95.76%
# Iteration 16501/20000: training loss 0.1498
# train accuracy: 97.14%
# Iteration 17001/20000: training loss 0.1098
# train accuracy: 97.75%
# Iteration 17501/20000: training loss 0.0876
# train accuracy: 98.42%
# Iteration 18001/20000: training loss 0.0542
# train accuracy: 97.64%
# Iteration 18501/20000: training loss 0.0988
# train accuracy: 98.30%
# Iteration 19001/20000: training loss 0.0751
# train accuracy: 98.14%
# Iteration 19501/20000: training loss 0.1069
# train accuracy: 98.33%
# Iteration 20000/20000: training loss 0.0506
# train accuracy: 98.91%

# %% [markdown]
# Now let's evaluate the trained model on the held-out test dataset to see if it overfits. How does it perform? Please report the final training/testing accuracy.

# %%
set_seed(12345)
Evaluator(test_dataset, multip_model, 'test').eval_split(multip_trainer.device, print_example=20)
# Out:
# test accuracy: 85.00%
# Prediction: 26 x 61 = 1586, correct answer: 1586
# Prediction: 19 x 12 = 268, correct answer: 228
# Prediction: 31 x 92 = 2852, correct answer: 2852
# Prediction: 44 x 53 = 2272, correct answer: 2332
# Prediction: 89 x 8 = 712, correct answer: 712
# Prediction: 91 x 88 = 8008, correct answer: 8008
# Prediction: 6 x 59 = 354, correct answer: 354
# Prediction: 39 x 34 = 1326, correct answer: 1326
# Prediction: 94 x 35 = 3290, correct answer: 3290
# Prediction: 28 x 20 = 560, correct answer: 560
# Prediction: 54 x 98 = 5292, correct answer: 5292
# Prediction: 91 x 79 = 7189, correct answer: 7189
# Prediction: 79 x 52 = 4008, correct answer: 4108
# Prediction: 78 x 59 = 4602, correct answer: 4602
# Prediction: 35 x 8 = 280, correct answer: 280
# Prediction: 71 x 33 = 2343, correct answer: 2343
# Prediction: 1 x 10 = 10, correct answer: 10
# Prediction: 64 x 79 = 5056, correct answer: 5056
# Prediction: 5 x 8 = 40, correct answer: 40
# Prediction: 69 x 20 = 1380, correct answer: 1380

# %% [markdown]
# Now, let's plot the training loss.

# %%
plt.plot(multip_trainer.train_losses)
plt.xlabel(f'Iteration (every {multip_trainer.log_interval})')
plt.ylabel('Loss')
plt.title('Training loss history')
plt.savefig('multiplication_loss.png', dpi=256)
plt.show()
plt.close()

# %% [markdown]
# # Section(C) Train a model to tell stories!
# Now, let's train a model to tell short stories!
# We are going to train the model on the [tiny stories](https://huggingface.co/datasets/roneneldan/TinyStories/tree/main). Please open the link,
# download the **TinyStories-train.txt** file, and put it in your **data** folder like below.
# ```
# HW4 /
# --| transformer.ipynb
# --| data /
# ----| TinyStories-train.txt
# ----| ...
# ```
# Here is one example:
# *One day, a little girl wanted to paint. She went outside, and looked around. The grass was green, and the sky was blue. It was a mild day, so it was perfect for painting.
# The little girl began to paint, and she used all the colors from her box of paints. Red, yellow, and blue. She painted on the grass, and she made a beautiful picture.
# She painted flowers and birds, and she was very proud of her work. The sun was shining, so everything looked very bright.
# When she was finished, she stood up and looked at her painting. She felt very happy, because she had made something beautiful. She knew she would always remember this mild day and the painting she made on the grass.
# After this, run the code in the cell below to load the stories.*
#
# Now let's load the dataset you download and run the cell below to convert the loaded stories to a dataset class to use.

# %%
# Out:
# drive/  multiplication_loss.png  sample_data/

# %%
# file_path = './data/TinyStories-train.txt'
file_path = '/content/drive/MyDrive/HW4_rev0/data/TinyStories-train.txt'
unique_chars = set()
data_len = 0
with open(file_path, 'rb') as file:
    while True:
        chunk = file.read(int(1e7)) #we do this in chunk to make it compatible with limited memory
        chunk = chunk.decode('utf-8')
        data_len += len(chunk)
        print(data_len)
        if not chunk:
            break
        for char in chunk:
            unique_chars.add(char)
sorted_unique_chars = sorted(unique_chars)
assert data_len == 1922767089
# Out:
# 9990541
# 19986053
# 29979590
# 39972496
# 49964221
# 59954744
# 69947926
# 79940655
# 89933160
# 99928581
# 109919710
# 119910748
# 129902928
# 139896391
# 149888178
# 159881199
# 169873894
# 179869931
# 189863959
# 199856631
# 209848705
# 219841890
# 229833658
# 239825767
# 249818837
# 259807060
# 269801357
# 279792976
# 289786644
# 299774936
# 309767611
# 319760703
# 329752566
# 339745445
# 349737886
# 359729917
# 369719428
# 379709871
# 389702304
# 399692943
# 409687812
# 419679435
# 429670934
# 439665761
# 449656535
# 459646571
# 469636971
# 479629305
# 489624570
# 499616200
# 509607173
# 519600427
# 529592271
# 539582706
# 549575280
# 559570986
# 569563255
# 579552136
# 589546001
# 599536655
# 609526751
# 619519615
# 629513148
# 639507741
# 649498613
# 659490898
# 669483078
# 679474017
# 689465989
# 699458313
# 709453334
# 719447801
# 729439368
# 739431062
# 749421700
# 759410541
# 769401244
# 779391457
# 789381979
# 799371128
# 809364056
# 819358481
# 829352799
# 839344304
# 849337143
# 859327322
# 869319666
# 879313146
# 889307503
# 899299915
# 909294765
# 919283521
# 929274636
# 939265275
# 949256402
# 959249497
# 969241652
# 979236771
# 989228170
# 999220263
# 1009212178
# 1019204370
# 1029195575
# 1039189202
# 1049183225
# 1059172896
# 1069167441
# 1079161599
# 1089153810
# 1099146369
# 1109135381
# 1119128703
# 1129118632
# 1139110356
# 1149104344
# 1159096108
# 1169089968
# 1179084927
# 1189075863
# 1199066150
# 1209060773
# 1219053020
# 1229047728
# 1239038394
# 1249031157
# 1259021800
# 1269015723
# 1279008653
# 1289001733
# 1298994127
# 1308984817
# 1318977419
# 1328971627
# 1338962816
# 1348955304
# 1358944787
# 1368938055
# 1378929344
# 1388917144
# 1398908572
# 1408902678
# 1418892205
# 1428885142
# 1438877617
# 1448869343
# 1458860528
# 1468851663
# 1478845419
# 1488836788
# 1498829930
# 1508821355
# 1518811974
# 1528802240
# 1538791152
# 1548784395
# 1558777009
# 1568766323
# 1578758409
# 1588748180
# 1598739916
# 1608732246
# 1618721087
# 1628712778
# 1638705051
# 1648695189
# 1658687382
# 1668681100
# 1678672895
# 1688663148
# 1698656438
# 1708645793
# 1718638100
# 1728628642
# 1738620594
# 1748612771
# 1758605562
# 1768597481
# 1778591322
# 1788584511
# 1798577789
# 1808568674
# 1818561092
# 1828555189
# 1838547275
# 1848542049
# 1858533826
# 1868527713
# 1878520066
# 1888509566
# 1898501647
# 1908495582
# 1918487342
# 1922767089
# 1922767089

# %%
class StoryDataset(Dataset):
    def __init__(self, file_path, chars, data_size, block_size):
        self.block_size = block_size
        self.loader = self.read_in_batches(file_path)
        self.data_size = data_size #1922767089
        vocab_size = len(chars)
        self.vocab_size = vocab_size
        self.stoi = {char:idx for idx,char in enumerate(chars)}
        self.itos = {idx:char for idx,char in enumerate(chars)}

    def get_block_size(self):
        return self.block_size

    def __len__(self):
        return self.data_size-self.block_size

    def __getitem__(self, idx):
        seq = next(self.loader)
        indices = [self.stoi[s] for s in seq]
        x = torch.tensor(indices[:-1]).long()
        y = torch.tensor(indices[1:]).long()
        return x, y

    def read_in_batches(self, file_path):
        with open(file_path, 'r') as file:
            while True:
                batch = file.read(self.block_size)
                if not batch:
                    file.seek(0)
                    continue
                yield batch

block_size = 256
train_dataset = StoryDataset(file_path,
                             sorted_unique_chars,
                             data_len,
                             block_size)

# %% [markdown]
# **Notice**: There is NO EXTRA CODE for you to implement in this section. You can directly reuse your code that you implemented in section(A) and (B). However, the model we are going to run is larger than the one from the section(B), therefore it is going to take <span style="color: violet;">**significantly longer**</span>, especially when running on CPU. Therefore, please start doing this **AS EARLY AS POSSIBLE**.
#
# Again, as training this model requires longer, it is possible that training breaks and you lose all the training progress, therefore if you are worried about this, you can refer to [PyTorch checkpoint](https://pytorch.org/tutorials/recipes/recipes/saving_and_loading_a_general_checkpoint.html) to save and load checkpoints while you train.
#
# In early iterations, the model will not generate anything meaningful, but as you train the model for more iterations, you will gradually see some interesting stories. The stories can be **imperfect** because we are only running a small model, but it should generate real words mostly, and follow grammar rules to some extent. Don't worry if the story is longer than the maximum length(1024 chars). Feel free to run it for longer (increase max_iters) or make the model size larger if you have time and want better results, but the default setting should be good enough.

# %%
from transformer import GPT
from transformer_trainer import Trainer, Evaluator

set_seed(12345)
# torch.cuda.set_device(1) #you can ignore this line, it's to switch cuda device

n_layer, n_head, embedding_dim = 8, 8, 256
story_model = GPT(n_layer,
                  n_head,
                  embedding_dim,
                  train_dataset.vocab_size,
                  block_size)
learning_rate = 1e-3
max_iters=15000
story_trainer = Trainer(story_model, train_dataset, learning_rate, batch_size=64, max_iters=max_iters)
story_trainer.run('story')
# Out:
# running on cuda
# Iteration 1/15000: training loss 5.5208
# Story (1):
# Once upon a time CC′a	′.e e ‒i‒e6ed′  aCie. a  Ced a	. 6 ′‒ a莉′id′′C′ 6 de6 ee d. eCC  ′′′aaa 6d‒d ′a C ‒ .di  C6 ia  6e ′.eC e a .6 ′ ‒e a‒	d ′i 6de′aC′.‒ 莉   ′C.  aed‒a.C 	′ede6 ee′′  daed  莉a6   dd.aeCe a.    6.‒e 6	6 6 6  6iC  ..‒  a6d‒e′e莉d ′′.C6ee Ced e      e ‒′    ′6 aaC.‒‒	a 6 6ea  aCeC e  e ‒a a.eCe6.Ce a ..a‒a.′6C eC′	ed′.6 e ‒‒i ai ‒ C a6i′C  ii6  6 ′  i C6C ae	e.6.eaC′. 	 e   e′ aa6i6.′C6  ieC′  ‒a‒ i6  .aii 	‒C′a6.aed C    i a6i .C′	6. 6 eCd    ‒Ca  a   . e ea    ′iae.   a ae  ′ a ‒ Ce 	dae6a.    ′i6ia	6id	   ′	aC6分′   	ee6.id aaii 6 ‒ edi‒′e6aC′eC‒. .e a ′ea C   ′ee‒    . 6..ae‒.iCC′.6e′e.a  6	e′ .6 e 	d′  e6Ci a6i ‒  ‒.ea′ .C C.	6C . e  ′ 6a i ′ea  	 ide.e  6  i‒e a   e ′iee     ‒ .eeCa	e′′′6C a eae′′	ea ‒‒e‒ 6eaa.e′Ca  	  .C .	Caaeaa	.  a . CeC′C‒′ ′ ed a′ a	d′.  	  	id a 6 e e C . ‒ a	 .分a6  6  ′	.66 	 e′  6   a ‒ aaC C  	   .i  a  ′′ Ce    i..C′′ a  ‒ed 	d‒..   eC 6e ′e C eaa‒	 ‒.  	a′′ .C  CC   ‒ ′	a e	′  ′a.‒6.C 	   ae‒ a. ‒ii.	‒i.e‒ C.C e′ ‒ ai 	 e e  ′aC′   .a	ai 6C CC6e‒ a. a	e6 ..e  C′.6i6‒′ed 	‒′a′e
# Story (2):
# Once there was an ee  .a莉‒ ′i  a e‒e6d′ 6i.   e		6   aC ′ade66  ′dd 66e e′‒6da e‒ea′ ‒.a   d Ca	 d′ ′aC.6.‒ad6e iC′. ′′. d′.  ′da‒ 6 e	  e eae i e iddC 	.a  6  a 6 eC C 	ia di‒ a  e66C . i莉dCe6a‒e  ′′  .e.′a  ‒  .aC6e‒e′e dd C e	6e   6′e e ae  d. ‒C‒Ca6 ‒ 6 C‒	  e ′	 6	Ca′′i 	 e	 6ie e ′e 6.aa.  e. ae 66 iCi ee C6C  i.i .′ ..     C. i a	.a ae ee 6′6′.   aae	i a  e  iC 6‒′ aCe aCa .C′ C 6ie..eaea    aC   ′   C C‒a. 6e‒ C ..6′ .C.C   .‒i.  C . C 6e 	 .6 ae .a e e. ′a. C′.eCeeee′ eC′a ia‒6  C ieCi‒′C  . 6  a6′ 	a‒ e 	e CC6 	. e6Ca   e 6 e   .a 6 ′eae  a  6 .e. e.e    .′′ . a′′6	 C′6 C6 i.e′e Cd e  C′ae′	ea 6	6′6ia.eeCee   6..e  ‒ 6i′ 6 i i..′ ′	e e‒e.′ e	 	Ce C‒d 	 	ed  a ‒d  .a Ce   CC ae	  e 	′ e ii.d6CC′	 C‒. i6 	d6	eee6 . i   ee  Ce 	ieCd.e 6 . a     ′  ′i C′ i . a‒Cd‒i′6i  a′ e6e 6a 6‒′ 6′ ′ia6C   .e‒e.e  6  a   	.  C ′	 i 	 .. . .ea′.′ 6 ′ ′	 e6 a e′e ′  ′ai6.C6C′.分a. 	e66i6′ e.     e′. .‒‒.  .  	′6.aea‒ id  Cdie66 ′ ‒i	 ′i  6  ie.	ae   .	aa6   C i  ‒C i C′	 	C′ a  Ca′ a  ′′. e  .‒e a′CC ′ a e 	eCa	6aC a6ea′ie e 6i   	.′6
# Story (3):
# One day. 	莉 a.6 .  .Ce′ aie ′e . ′   i ′ 6de66e 莉6eC  ‒e6′.莉aa.‒ea dC 6da莉C  ‒CdaeaC′‒dC  ‒6 ea d  ′ . d′′ .6e 6  e ‒6 iea莉C.eCd . C C66  .d C  ‒d. 6.莉C′ a  aiaCaC ‒e  C6  6  ′6ae6e ′′.ae  d. id ‒a‒da . 莉.      ′a a    	d e eC eae a‒ 6′e e6.a . e′.ai‒ .. C 6idii.i‒e ′.a.i6..‒′  i ..a ee eda e6 ′Ce e   ′.6CC a. ‒Ce ‒	ii 6eC   iiC′C e	.aae  a 	C6	ed  ed  .′.ea′′ 	aCC. 	e  .   ′ . aeeeee i′. ea 6e	.e 66  C ‒ aeaa′i  	6‒  	 ‒   ′..e′6′ 6 ′ iiaC ..a.Ce′ ‒   a‒′ iC ′ee.	′ .	.′.e‒aiee‒e   ′ i′    ‒C	6e′ ′a′d    ae ′  a.′   C .a	Ca .a‒e6 C  	aCCC 6 6′   eC  	e.′ e‒C6. ‒66‒a.e  	e e′ ′aC e   e a C‒	d6 eae a′ 	 6 .′C6ia′e 6.e6ed a′d .Ce .6	C′ ′C Ce′. ′C′d‒eCiCCee   aeaCC ai′ .	i e e     C ′Ci a...CCi i.Ca6.‒‒6 6e.′a ′a.. a e ′e  aaa 		. .   	6e′′CC  ′a′.. ′  e	edeCd .分ea C C  C 	 ‒e ′	. .	C.e.a ‒‒‒′a	aCe‒  . a ‒ a‒′.6‒‒  ′.a‒Ca′6  ′′.  a . ‒C ‒ ′i6 C ae.C. .ie   ′ i    ′i.  a  .C iC.aaC a.iai′C . ii ′ 	. i ‒ .′	C ..6′a	d 	a 	aia    ′	6′ae6 C6   6	 C a e .    ‒ae‒a	 	 i′iC′ 6 e	..  	6 ′		′ i	.′ Ci eaC i‒  6i a 	′Ce ′ ′ae eC 6′
# Iteration 501/15000: training loss 1.7922
# Story (1):
# Once upon a time hin bom the motind, "I walle pat a and it, be a look too cher an to and the soul. They saw saw the their to proce to the ime to soma. She ad and trie it to boulte. She the a days to the whing so pok it. She they hownthin's to her. He der was was terir sarked tlit bootat ithat twe at fun it and ware forended she outher. Her did ad sallled and Tis the comeltele, "Doved buron, "Lily't, her she cacyir to but flig therat a shir shomed thid. The art bane, anve bry happy her was shey with belit fins flird thens in alllings theim in now toge soons. "Wan, hey as at goo therar, I downe aver the ats and and wat they cad bill theis, she sploot to tich becat igh thor they. He domm they dad bon the she said and shie. She aned the sort as in it then togart.
#
# Story (2):
# Once there was an take. It, "Why bolelle we the to pry!"
#
# Story (3):
# One day, he heave a she clooooth her butle the pil bear the cat shellle. They we tho the they felt. It was shey bich is the wie fat fors fil. She he hear hey had lay shee betig the walfoll she and and he fof and.
# Her she saw to sitede with was to the go theirtth and hage bot ir sthe tore.
# Lily "Lily, "Lely wis's, he shit hit tat ir her an alll skeated.
# Bunly here want souck and Somalld the the touet.
# They scared as aid "Tim sthe was and the bor icith."
# She wim bigl lovens it but it and "Lut to am the sant longath Thim, "Lou," Then dome lanet and big, Sheche and his and live an saw the that bit to hes atingede. They the dot claver they. The my sared tid sogld out the hel the gigar in. They litle wile. They hey saw sot diggl.
# She smaid, The s at and santes Sane. Hent sad shirrr, "Yeam. "Le lookled to the sto cat tat welke to take boy."
# Lily dampp werees tollt frated. They loty they wigh all agro brom.
# The helt bill there arake! He they was hitan ifomm. "I dou d and hellp tooo the ipp to tire stometh int in then brat
# Iteration 1001/15000: training loss 1.2703
# Story (1):
# Once upon a time, there was silly folly and a look to play was surprited. He learned so happy careful the park. She she creation on her holded see the facet, but the gran was happy.
# "He and took are things tround the sunnely," Mimm. She had genered the counsey and pieces to glad something around again. It was she she wlutted and befounted the boy allyings went her curious. She see it finally to play with them stop it, but on, the soilled the play deatil that and it of was very to them bach oloused uncoous, she was a pilaned.
# "Yes!"
# OK, herer momm, whisghed the breear. She was shared it was ange, but Tomm around as beecause tricked to fuzzy felt out and tlapped to mick and was be ach. She coot his friend.
# They but to the pirlede and she was and cleaused and the sharews. They decidedied to want to share the gon and shower his callet of found fell animals. Timm and She was a hug it do saft was thought and cleanos allways fun the twichered and looked under and they playues withen his with the beest it choure it and they dad fte
# Story (2):
# Once there was an dear it. The little was clost. The bathr and was dolls. She said "Sara," the pink away her toys friend. He did not get with closer the store.
#
# Story (3):
# One day, Lily went and played to him. She said she the house and fedling away. She was happy that the should called. She was happy as happy and for cildren awayay. She was so happy that them see it if him. She seet sticks the twere fine will be forgot and scared angreed of the scare it it. Sudddenla careful the stories, the starter to her.
#
# Iteration 1501/15000: training loss 1.0356
# Story (1):
# Once upon a time, Tom found a little girl warry and curious find that was she had sure to be feel anyure at staying together.
# The bear wend to see sorry the fun sack. He looked around alout of for and showing it was stangelt. They were so happy and they were inside. They said they sun and always waited it. At they waved it to have and they bug coming hugs.
#
# Story (2):
# Once there was an around, she saw now to pick the store bag. She was very proud of her, so so her mom sunsted about the sun.
# After a while couldn't catch it, looking. Benny learned that it of the food. This been saw tiny and watched her bright huge and asked ic with it.
# Suddenly, "You're hard helpe you candy?"
# Her mommy asked in her butterfly slighed. She came up and firstand the stackle treasure. After they said no. They had every disappeared, her mom said, "Do you look light special. They all they came and hard afraid, laughed." Mark smiled and ran inside and started inspoteced the floppit around that she was so much fun or adventually and feeling again.
#
# Story (3):
# One day, her mom mommy said, she was happy to her mom. "No, we can! I culd sad and decided to eat what you can different enoughbone!"!"
# Jane looked after at sorts and smiling, something she needed of some petench thing came again.
# "It's a small!”
# Mom, repeted up and the girl sailed in and sailing a bird hug the secrful in the park with her toyses!
# Sudddenly, a mom sheepped on the deen of them. It was time for a nearble. He wouldn't believe them around, exploring the dooor.
# The moral of the shellls looked at the passs of the gem. The old man was very happpy and said, “You should be able to go home for you!”
#
# Story (3):
# One day, Sarah saw the ship and her mom wanted to go away. She gittened the soft one said and soon she tried to help us study in the task.
# Sarah smiled and said, "Hello showed our tree who's own?". Sarah said, "I can't be right again."
# Sarah, found a way with the peerfect dooor and her bush. She gave them the stick fast back and said, "Wow, I don't know I want to get the toast old magic peacefe!"
# Sarah was so happy and scarefuled, she was tired for the perfect to get icy adventure and asked what it was, so she rode.
# Mommy said it was her astrange trick! She said, taking a farmar in her sand. She said to Angh and said, "I'm perfect. Where are you going on the grass?"
# But, Tommy was so proud of her. He asked, "Yes, why dad, I'm going to eat my foood?"
# The moral of them as soorth as a glass both carefully around himself. He put it back in his neew foods and that weren't evalier shiny.
# The glasss came their wallks until they were very happpy and having such a little song.
# The moral of them, it was so happy to be safe
# Iteration 4501/15000: training loss 0.8590
# Story (1):
# Once upon a time, there was a lady and a little boy named Timmy. His name loved to play outside in the park, his name was very curious.
# One day, Timmy wanted to go inside with the boy to be careful with his name was Jilly. He smiled, and said goodbye.
# Timmy slowly shouted "Let's play with." Suddenly, the sheef heard a friendly daughter. Then we have something strange in it and he had an idea. Wishing that is others.
# Jill showed Jill throughm the shoe told her. Timmy was always having a strange that he didn't know what to do.
# Finally, the friendly little girl came to help. They were happy and clean.
# They clapped the stranger from the clouds and their friend thanked the little boy for being creative. The little girl said goodbye to them but theys were too small far to choose it.
# At the end of the he landed around, the little boy asked him what to do.
# When he was invited the land, the little girl said, "Mary, can I hurt you together?"
# The end.
#
# Story (2):
# Once there was an unknique bunny came to the bank and wanted to burn some last too much. The bunny was able to go and he loved to play with the bunny satisfied out his cone. He said that the bunny was having finish.
# They showed the little bunny how to get one.
#
# Story (3):
# One day, he wanted to explore the park. His favorite friend came outside and searched, as Joe looked at it. He saw lots of of delicious breed and cooled for him before.
# The little girl thanked the little child and the friendly girl had a great delicious bow.
#
# Iteration 5001/15000: training loss 0.8240
# Story (1):
# Once upon a time, there was a little girl named Spot. She liked to run towards her favorite wall out on the wall. She wanted to catch it as she had lost her colors of her favourite wall. She thought it was not scared, like a big ball or her friends.
# So Spot started to collap and hugged them a big smile. She said they thanked Spot.
# Ben realized it was going to do it. Spide the ball, scorered the doors around her friend. They learned that it was blink. They started to cry.
#
# Story (2):
# Once there was an old castle who was very excited, who were so bright.
# One day, she was walking around the sidewalk and she sparkled away. Suddenly, the castle had made a book out of a night lade and she was so proud of her for singing some signs.
# Mum and Dad said yes, but they did not like to stay away. The farmer asked her favorite to touch the farmer too. Lucy addoded the day put and tried to purr it in and legs it cleaned up the water.
# The moral of the stor is scared of you. It was so fresh that you made sure it to stay away from more, so of you answer at the sadcks and stop cleaning home in mpight with her stomache wanted to call them.
# "Wow, what is that?" Tom asks.
# "Can we slow at first, Mom?" Tom asks. She hugs.
# "Wow, what is it? You saw your new pond is more. Don't curiage swoop at the saracker and could not believe the lanngue was brilliant in agther. It is nothinld a pond of paittient is bigg, colorful again and spent how to cross your friends is."
# Don't worry, where are sweeetie and curious to shoot them out of thin
# Story (3):
# One day, they decided to show it to each other, the top was sour. The twirles were the poster on their faces. She saw it was a big box of leader.
# "Don't worry," the faces said. She was so surprised and dizzy had could have her feet and solved each other for the poster to play with it and the box. The fances was bad and helpd Mom when she saw an endergouction, so the leader sailed around her and got sick.
# "Lila and Ben, what is the mom?" she shouted.
# "Look, Tomm, we can go outside and seee if it did not let make a better smile."
# "What is that?" Tomm asked.
# "We were playing in the might first with you? We did not want you want to go with me. He loved to play with youth them all danced again.
# "Soup, mom, my peicesial is new friend too. It is my thick for so much and new."
# So they left the shick too, the wing taugla. They say, "Look, a wing in the storm won!" Annd Ben smiled and telled his mom what he was going.
# They played with the comfort box of cleare and set offf on the bucket. They played with them all kinds at of
# Iteration 5501/15000: training loss 0.8229
# Story (1):
# Once upon a time, there was a big boat. The boat was no loved to swing and twice and blue fish. The boat was very scared and he twirled away.
# But then, he watched someone was started to fall out. It was like that the boat said "Happy, but I'm so proud that I."
# The boat grabbed a big surprise, and went back to the climb. It forgot all above the climb to the bear. The princess were happy and enjoyed their waterts. They started to climb the blanket that the boat was feeling happy.
# After the princess opened, the boat and be released that all the other people in the boats were having better, they swill cheer again! Its face changed them on their bags as they climbed and have a serious snack together.
#
# Story (2):
# Once there was an emergency bug. It was a big bug. He liked to play outside with the room.
# One day, a mommy went outside to play. He saw something special - colorful, a little bug crawled up to his favourite adventure.
# "It was a very tall," his favorite squirrel circleed. The mommy said, "You must be careful noise. I can still be an ingredient, it's important to talk about it."
# He hanged a surprise in the woods. He thanked the fapce and stirred his favorite toy to carefully. Timmy said, "Do you like it?"
# So he took a special puzzle, away! Bricks, his parents carefultelly tightly and he was very sad.
# Timmy ran to his power, saw something special, it started to cook again. He sat on his prants spot and sat in his parents. "Hello pine! What are you doing?"
# Timmy said, "Ouch can I hurrry?"
# Timm smiled. "That can I destroy is?"
# Timmy helped Billy for so he heard his nose ones. He walked home, fed teethes bear, and he said, "Will you learn noises all day?"
# So, Sam and Timmy spread his toy and she took off a littlegson. Happy shooute
# Story (3):
# One day, her parents appeared in a bush was walking around. She saw a tap and said: "Let's take them to the park and we can buy side.".
# Julisa didn't get the cup on the fridge asked, "Can I do that?"
# Lucy said, "Sure!"
# Mom and Dad went to their park. They said, "Think it is a rare afraie."
# They said, "We can do me the cup. Let's give your mind's head."
# So, Julisa felt so scared. Sooon, they reached the cup and started to go swing. They were grateful and having lother. Lily was having lots of fun when they ran slowly but hurt a night.
#
# Iteration 6001/15000: training loss 0.8223
# Story (1):
# Once upon a time, there was a little bird. It was a special bike. It was colorful to the bin.
# The bird rolled the bike. He thought about the frame. He had a lot of fun days. He asked, "Wow, what is in the spoiled?" His mommy was proud of him and gave Bike a hut. Lily said, "That is a good bike! Now Is it a shiny flower." The bird said "This is our best day. Who is it for his look?"
# "I'm sorry, Billy. I'm just that noises," Lily said.
# Her mommy said, "Wait, let's go inside and call her delicious ball. Let's go oon an adventure!"
# After playing with her clothes, Lily's dadmy and her daddy gave her a big hug as a small puppy. Lily was happy and followed the pup to her mommy's clothes home. Her daddy was happy to see her and they let her feel better.
#
# Iteration 14501/15000: training loss 0.6981
# Story (1):
# Once upon a time, there was a big boy named Tim who was walking in the park. He saw a frog with a chattest stick. Tim had a badpy stick that he loved to play with. He had a picnic that the stick spilled on the stick.
# One day, Tim met a big tutor. He gave the tutor shark his toys. He pushed it from the tall, shakes and laughed. Tim was very happy as he could. The tutor dropped his toys. Tim was too angry. He tried to rub the rock away, but he was also angry.
# Tim watched the tutor go far away. But slid down slimber to the toys of the tall metal tree. But the tutor was fast and he couldn't scleeam. He dropped the toys and ran away from the ground.
# "Help, help!" his mom cried. She hrang the toys gently and ran to the toys. She picked up the paper and tried to guess it with Sue.
# Lucy followed Tom to the toys and saw Tom's hlock. She guessed the paper glitter and luckied too. She tied him on the hedge, the paper tried to school the paper.
# Lucy's dad walked to the trock gets and the trip. They were having so much fun. They did not
# Story (2):
# Once there was an ordinary food. They liked to draw with their buckets. One day, they decided to draw on the wall. They braw ancient colors and size. They dragged on their buckets and went to the store.
# "Let's reach the buckets," Sam said.
# They told their friends they were angry. They said they would help put the buckets on them and try their buckets. They said maybe they can find something that you will be more careful with. The buckets love scared. And they will give them peace to the waves. Now, they are friends.
#
# Story (3):
# One day, a little little mouse named Tom came to play. Tom saw the mouse waiting for the mouse.
# "Hello, mouse!" Tom cried. "Don't worry, we will see you."
# The mouse took Lily and pressed her toy pole that he came in the room. It was the most things that happened.
# Tom whispered, "Sorrry, mom, dad. I just wanted to play tag."
# Mom smiled and hugged her. She said, "That's wharm of your toy, Lily and Ben. Your toy pole is not a good pole. You are a little more belt in the park. It's okay for you."
#
# Iteration 15000/15000: training loss 0.6190
# Story (1):
# Once upon a time, there was a little bird named Tweety. Tweety loved to play with his rock with all kinds of toys. One day, he found a crack that made him go vroom. They were very happy to see the crack hiding some pictures.
# The crack bought the story and checkered her eyes.
# Tweety ran to the city and said to the crack. But it would not come true. Sam sahed the rick to think where he would find it. Mr. Smith looked around and saw many different things to do. He had no finguing to come inside next to the forest.
# At the end of the dark, Lily found a smalll hole in the window. She was so happy to have found the honey for a long time ago. They said, "Let's go inside, Mom!" They hugged Lily and said, "Thank you for taught us to be kind. And take the honey soon soon." From then on, Lily practiced pupping and hit hands on the walllet. They had so much fun with their new honey that took Lily honked in dough.
#
# Story (2):
# Once there was an old man. He wanted to back to his truck. He could not wait to try it.
# "Let's go, Tom," his mom replied. "Maybe we can have something else too."
# "OK, Ben," Tom said. "We can make something big and beautiful."
# They worked together to display the truck. Lily was happy to show them how to fix them them. Her favorite toys mixed so they could show them alll her friends. They were happy and gentle with their friends.
#
# Story (3):
# One day, Tim was playing with his friend, a little fish, came and saw a big tree with a big rock, and said, "Help, what's inside?" Tim agreed, and Tim followed Tim for a long time. They scooped the rock and turned around the tree, packing from the tree. They were happy to be their friends.
